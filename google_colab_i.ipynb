# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
# !nvidia-smi
# !pip list
# Out:
# Sun Feb 23 12:17:40 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   74C    P0             33W /   70W |     926MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install ultralytics

# %%
# !unzip ./datasets/datasets.zip
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#  extracting: 2_val/labels/train/V_AIRPLANE_056_4_231.txt
#  extracting: 2_val/labels/train/V_AIRPLANE_056_4_241.txt
#  extracting: 2_val/labels/train/V_AIRPLANE_056_4_251.txt
#  extracting: 2_val/labels/train/V_AIRPLANE_056_4_261.txt
#  extracting: 2_val/labels/train/V_AIRPLANE_056_4_271.txt
#  extracting: 2_val/labels/train/V_AIRPLANE_056_4_281.txt
#  extracting: 2_val/labels/train/V_AIRPLANE_056_4_291.txt
#  extracting: 2_val/labels/train/V_AIRPLANE_056_4_301.txt
#  extracting: 2_val/labels/train/V_AIRPLANE_056_4_311.txt
#  extracting: 2_val/labels/train/V_AIRPLANE_056_4_321.txt
#  extracting: 2_val/labels/train/V_AIRPLANE_057_5_001.txt
#  extracting: 2_val/labels/train/V_AIRPLANE_057_5_011.txt
#  extracting: 2_val/labels/train/V_AIRPLANE_057_5_021.txt
#  extracting: 2_val/labels/train/V_AIRPLANE_057_5_031.txt
#  extracting: 2_val/labels/train/V_AIRPLANE_057_5_041.txt
#  extracting: 2_val/labels/train/V_AIRPLANE_057_5_051.txt
# ...

# %%
import os
path = "/content/drive/MyDrive/Colab Notebooks/Anti-UAV_colab"
os.chdir(path)
os.listdir(path)
# !python 1_train.py  //注意colab中执行命令前要加！
# Out:
# ['runs',
#  'Untitled0.ipynb',
#  'best.pt',
#  '2_val.py',
#  '3_Predict.py',
#  'test',
#  'models',
#  'UI',
#  '4_tracking.py',
#  'datasets',
#  '.ipynb_checkpoints',
#  'yolo11n.pt',
#  '1_train.py']

# %% [markdown]
# **yoloi.yaml    epochs = 50, batch = 64, imgsz = 320:**

# %%
# !python 1_train.py
# Out:
# 动态路径：train_yoloi.yaml_2025-02-23_11-36-57
# WARNING ⚠️ no model scale passed. Assuming scale='i'.
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("./runs/train_yoloi.yaml_2025-02-23_11-36-57/weights/best.pt")

# Customize validation settings
validation_results = model.val(data="./datasets/data_val.yaml", imgsz=320, batch=64, conf=0.25, iou=0.6, device="0", project = "runs", name="val_yoloi")

print(validation_results.box.map)  # mAP50-95
print(validation_results.box.map50)  # mAP50
print(validation_results.box.map75)  # mAP75
print(validation_results.box.maps)  # list of mAP50-95 for each category
# Out:
# Ultralytics 8.3.78 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11 summary (fused): 70 layers, 618,728 parameters, 0 gradients, 4.2 GFLOPs
# val: Scanning /content/drive/MyDrive/Colab Notebooks/Anti-UAV_colab/datasets/1_train/labels/train.cache... 16451 images, 0 backgrounds, 0 corrupt: 100%|██████████| 16451/16451 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 258/258 [06:54<00:00,  1.61s/it]
#                    all      16451      17408       0.49      0.355      0.402      0.171
#            AIRPLANE_IR       1817       1817      0.515      0.267      0.378      0.185
#                BIRD_IR       2024       2366      0.421      0.261      0.312      0.124
#               DRONE_IR       3982       3982      0.665      0.882      0.752      0.305
#          HELICOPTER_IR       1532       1532      0.417     0.0816      0.241        0.1
# ...

# %%
Results saved to runs/val
0.3318020144343662
0.598846514404591
0.31619897654995693
[    0.39298     0.37605     0.39247     0.78958   0.0097161     0.21525     0.29722     0.18116]
